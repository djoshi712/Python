# %% [markdown]
# OS module in Python provides functions for interacting with the operating system. OS, comes under Python’s standard utility modules. This module provides a portable way of using operating system dependent functionality.
# os.chdir() method in Python used to change the current working directory to specified path. It takes only a single argument as new directory path.

# %% [markdown]
# ### working with directories

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\djoshi'

# %%
os.chdir('D:/Python Intermediate') 
os.getcwd()
# Out:
# 'D:\\Python Intermediate'

# %%
os.mkdir('D:/python')

# %%
os.mkdir('D:/python/os')

# %%
os.makedirs('D:/DataScience/ML/DeepLearning')

# %%
os.rmdir('D:/DataScience/ML/Deeplearning')

# %% [markdown]
# ### Example

# %%
# # data preparation >> creating a csv file from the folder images
import os
import xlwt 
from xlwt import Workbook 
import xlsxwriter 

folder = 'D:/Research/3. bone-research/Mixed DS/bone_dataset/normal'
workbook  = xlsxwriter.Workbook('D:/Research/3. bone-research/Mixed DS/bone_dataset/normal/train.xlsx')
worksheet = workbook.add_worksheet()
print(os.listdir(folder))
images_list= []
i=0
for bone_type in os.listdir(folder):
    bone_type_path=os.path.join(folder,bone_type)
    print(bone_type_path)
    print(os.listdir(bone_type_path))
    for image in os.listdir(bone_type_path):
        images_list.append(os.path.join(bone_type_path, image))
#         images_list = [os.path.join(bone_type_path, image) for image in os.listdir(bone_type_path)]
    print(images_list)    
for image_name in images_list:
    i=i+1
    worksheet.write('A'+str(i), str(image_name))
    worksheet.write('B'+str(i), image_names.split('\\') )
workbook.close()
# Out:
# ['ankle', 'foot', 'hand', 'lower leg', 'wrist']
# D:/Research/3. bone-research/Mixed DS/bone_dataset/normal\ankle
# ['10_ankle.jpg', '11_ankle.jpg', '12_ankle.jpg', '13_ankle.jpg', '14_ankle.jpg', '15_ankle.jpg', '16_ankle.jpg', '17_ankle.jpg', '18_ankle.jpg', '19_ankle.jpg', '1_ankle.jpg', '20_ankle.jpg', '21_ankle.jpg', '22_ankle.jpg', '2_ankle.jpg', '3_ankle.jpg', '4_ankle.jpg', '5_ankle.jpg', '6_ankle.jpg', '7_ankle.jpg', '8_ankle.jpg', '9_ankle.jpg']
# ...

# %%
# if os.path.isfile(os.path.join(bone_type_path, image))

# %%
import os 
# Leaf Directory name 
directory = "baz"
# Parent Directory 
parent = "/home/User/Documents/foo/bar"
  
# Path 
path = os.path.join(parent, directory) 
  
# Remove the Directory 
# "baz" 
os.removedirs(path) 
print("Directory '%s' has been removed successfully" %directory) 
  
# All parent directory 
# of 'baz' will be also 
# removed if they are empty
