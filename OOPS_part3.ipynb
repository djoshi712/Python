# %% [markdown]
# ### Abstraction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Abstraction:
#
#   Abstraction (from the Latin abs, meaning away fromand trahere, meaning to draw) is the process of taking away or removing characteristics from something in order to reduce it to a set of essential characteristics.
#
#     In object-oriented programming, abstraction is one of three central principles (along with encapsulation and inheritance). Through the process of abstraction, a programmer hides all but the relevant data about an object in order to reduce complexity and increase eﬃciency
#
#     An entity is any singular, identiﬁable and separate object.
#
#     Abstraction helps in idenifying entities, properties and behaviors… what next? How do we model them in code?

# %% [markdown]
# ### Encapsulation:
#
# is one of the fundamental concepts in object-oriented programming (OOP). It describes the idea of wrapping data and the methods that work on data within one unit. This puts restrictions on accessing variables and methods directly and can prevent the accidental modification of data. To prevent accidental change, an object’s variable can only be changed by an object’s method.
# hiding data behind methods
# encapsulation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Example-1

# %%
class User:
    def __init__(self, name, password):
        print("from User class")
        self.name= name
        self.password = password

# %%
u1=User('Ram', 12345)
u1.password= 3457
print(u1.name)
print(u1.password)
# Out:
# from User class
# Ram
# 12345

# %% [markdown]
# ## Example-2

# %%
class Employee:

    def __init__(self, name, salary):
        self.name= name
        self.__salary= salary
        
    def display(self):
        print(f'emp name is {self.name}, emp sal is {self.__salary}')

# %%
class Student:
    
    def update_sal(emp):
        emp.__salary= emp.__salary - 5000
        emp.display()

# %%
e=Employee('Sita', 78000)
e.display()
# call static method using class name
Student.update_sal(e)
# Out:
# emp name is Sita, emp sal is 78000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-3d8da4a9848b> in <module>
#       2 e.display()
#       3 # call static method using class name
# ----> 4 Student.update_sal(e)
#
# <ipython-input-7-1682696e2557> in update_sal(emp)
#       2
#       3     def update_sal(emp):
# ----> 4         emp.__salary= emp.__salary - 5000
#       5         emp.display()
#
# AttributeError: 'Employee' object has no attribute '_Student__salary'

# %% [markdown]
# 1. Various object-oriented languages like C++, Java, Python control access modifications which are used to restrict access to the variables and methods of the class. Most programming languages has three forms of access modifiers, which are Public, Protected and Private in a class.
#
# 2. Python uses ‘_’ symbol to determine the access control for a specific data member or a member function of a class. Access specifiers in Python have an important role to play in securing data from unauthorized access and in preventing it from being exploited.
#
# 3. A Class in Python has three types of access modifiers – Public Access Modifier Protected Access Modifier Private Access Modifier
#
# 4. The members of a class that are declared public are easily accessible from any part of the program. All data members and member functions of a class are public by default.
#
# 5. Protected Access Modifier: The members of a class that are declared protected are only accessible to a class derived from it. Data members of a class are declared protected by adding a single underscore ‘_’ symbol before the data member of that class.
#
# 6. Private Access Modifier: The members of a class that are declared private are accessible within the class only, private access modifier is the most secure access modifier. Data members of a class are declared private by adding a double underscore ‘__’ symbol before the data member of that class.

# %% [markdown]
# ## Example-2 (Correct Approach)

# %%
class Employee:

    def __init__(self, name, salary):
        self.__name= name
        self.__salary= salary
        
    def getName(self):
        return self.__name

    def setName(self, name):
        self.__name= name
    
    def getSalary(self):
        return self.__salary
    
    def setSalary(self, salary):
#         validation code
        self.__salary= salary
    
    def display(self):
        print(f'emp name is {self.__name}, emp sal is {self.__salary}')

# %%
e1=Employee('shyam', 34000)
# print(e1.__salary)
print(e1.getSalary())
setSalary(21000)
# Out:
# 34000

# %%
class Student:
    
    def update_sal(emp):
        sal=emp.getSalary()
        emp.setSalary(sal-5000)
        emp.display()

# %%
e=Employee('Sita', 78000)
e.display()
# call static method using class name
Student.update_sal(e)

# %% [markdown]
# #### Example (Additional)

# %%
lst_employees= []

e1=Employee('Ram', 567777)
e2=Employee('Shyam', 785789)
e3=Employee('Sita', 985989)

lst_employees.append(e1)
lst_employees.append(e2)
lst_employees.append(e3)

# Average salary
sum=0
for i in lst_employees:
    sum= sum+ i.getSalary()
    
print(sum/len(lst_employees))

# %% [markdown]
# ### Question??

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer:
#
# 1. The balance can be set to very high/low value accidentally.(#stmt1)
# 2. The balance can be accessed or changed by user of the class.
# 3. The balance can be set to non-permitted value (#stmt2)
#
# Make balance a private variable ( __balance)

# %%
def __init__(self, initial_amount):
    self.__balance = initial_amount

# %% [markdown]
# ## object.__str__(self)
#
# If we try to execute following code without __str__ method then #statement1 will result in something like following in output window<__main__.Student object at 0x0191F850>•In order to have a meaningful string representation of Student object we can add this method and return a string. You may refer following link for more information

# %%
class Person:

    def __init__(self, personName, personAge):
        self.name = personName
        self.age = personAge
        
    def __str__(self):
        return self.name + ' ' + str(self.age)

# %%
p = Person('Pankaj', 34)
print(p)
# Out:
# Pankaj 34

# %%
class A:
    def sum(self, a,b):
        
    def sum(self, a,b,c):
        
    def sum(self, a,b,c,d):

# %%
10+20
# Out:
# 30

# %%
'abc'+'cde'
# Out:
# 'abccde'

# %%
'abc' * 3
# Out:
# 'abcabcabc'

# %% [markdown]
# ### Operator overloading:
#
# use any python ooperator for our own purpose using magic methods:
# 1.  +    __add__(self, other)
# 2.  *    __mul__(self, other)

# %%
class CSE_Subjects:
    def __init__(self, sub):
        self.sub= sub
        
    def __add__(self, other):
        l=[]
        l.append(self.sub)
        l.append(other.sub)
        return l

# %%
s1= CSE_Subjects('Python')
s2= CSE_Subjects('Java')
print(s1+s2)
1+2
# Out:
# ['Python', 'Java']
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
10+20
'hi'+'there!!!'

# %%
10*20
'hi'*3

# %% [markdown]
# ### Method Overloading
#
# Like other languages (for example method overloading in C++) do, python does not supports method overloading by default. But there are different ways to achieve method overloading in Python.
#
# The problem with method overloading in Python is that we may overload the methods but can only use the latest defined method.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class A:
    def add(self, i):
        print(i)

# %%
a=A()
a.add(2)
a.add('2')
a.add(2.4)
a.add([1,2,3])
a.add(2+3j)
# Out:
# 2
# 2
# 2.4
# [1, 2, 3]
# (2+3j)

# %%
# using default arguments
class Test:
    
    def sum(self, a=None, b= None, c= None):
        if a!=None and b!=None and c!=None:
            print(a+b+c)
        elif a!=None and b!=None:
            print(a+b)
        else:
            print('provide more arguments')

# %%
t=Test()
t.sum(2)

# %%
# using varibale length arguments
class Test:

    def sum(self, *a):
        total=0
        for item in a:
            total+=item
        print(total)

# %%
t=Test()
t.sum(2)
t.sum(2,3,4)
t.sum(2,3)
t.sum()
# Out:
# 2
# 9
# 5
# 0

# %%
# last method will be called
class Test:

    def sum(self, a,b):
        print(a+b)
        
    def sum(self, a):
        print(a)
        
    def sum(self, a,b,c):
        print(a+b+c)

# %%
t= Test()
t.sum(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-fc9f3299277f> in <module>
#       1 t= Test()
# ----> 2 t.sum(1,2)
#
# TypeError: sum() missing 1 required positional argument: 'c'

# %% [markdown]
# ### Inheritance
# - code reusability
# - Extend exsiting functionality

# %%
# overriding

# %%
class Parent:
    
    def property(self):
        print('cash+land+gold')
        
    def marry(self):
        print('ABC')

# %%
class Child(Parent):
    pass

# %%
c=Child()
c.property()
c.marry()

# %%
class Parent:
    def property(self):
        print('cash+land+gold')
        
    def marry(self):
        print('ABC')

# %%
class Child(Parent):
    def marry(self):
        print('XYZ')

# %%
c=Child()
c.property()
c.marry()
