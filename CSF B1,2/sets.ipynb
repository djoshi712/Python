# %% [markdown]
# ## What is a set
# In mathematics, a set is a well-defined collection of distinct objects
# 1. Set of even positive numbers less than 10: 2, 4, 6, 8
# 2. Set of perfect squares less than 10: 1, 4, 9
# 3. Intersection of these two sets: the number 4 <br>
# Python’s built-in set type has the following characteristics:
# 1. Sets are unordered
# 2. Set elements are unique and duplicate elements are not allowed
# 2. A set itself may be modified, but the elements contained in the set must be hashable

# %% [markdown]
# Immutable - A type of object
# that cannot be modified after it
# was created. <br>
# Hashable - A type of object that
# you can call hash() on.

# %%
a= 10
hash(a)

# %%
s= "and"
hash(s)

# %%
b= [1,2,3]
hash(b)

# %%
s= {11,2,4,5}
s, type(s)

# %%
d= {}
d, type(d)

# %% [markdown]
# ## ways to define a set:
#     1. set()
#     2. a= {,}

# %%
a= set()
a, type(a)

# %%
s=set("hello")
s, s[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ca2d41849715> in <module>
#       1 s=set("hello")
# ----> 2 s, s[1]
#
# TypeError: 'set' object does not support indexing

# %%
l=list("hello")
l, l[1]
# Out:
# (['h', 'e', 'l', 'l', 'o'], 'e')

# %%
s= {32, 2, 4, 64}
s, type(s)
# Out:
# ({2, 4, 32, 64}, set)

# %%
e= set()

# %%
se= {'hello', True, (2,3,4), None}
se
# Out:
# {(2, 3, 4), None, True, 'hello'}

# %%
sh= {'hello', True, [2,3,4], None}
sh
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-fa248e8b6a5e> in <module>
# ----> 1 sh= {'hello', True, [2,3,4], None}
#       2 sh
#
# TypeError: unhashable type: 'list'

# %%
hash((2,3,4)), hash([2,3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-43dce9696a7a> in <module>
# ----> 1 hash((2,3,4)), hash([2,3,4])
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## Example

# %%
def count_unique(s):
    '''
    Count number of unique characters in s
    >>> count_unique("aabb")
    2
    >>> count_unique("abcdef")
    6
    '''
#     Approach-1
#     seen_c = [] # O(1)
#     for c in s: # O(n)
#         if c not in seen_c: # O(n)
#             seen_c.append(c) # O(1)
#     return len(seen_c) # O(n^2)

#     Approach-2
#     seen_c = set() # O(1)
#     for c in s: # O(n)
#         if c not in seen_c: # O(1)
#             seen_c.add(c) # O(1)
#     return len(seen_c) # O(n)

#     Approach-3
#     return len({c for c in s}) # O(n)

#     Approach-3
#     return len(set(s))  # O(n)

# %%
def count_unique(s):
    new= []  
    for char in s:  
        if char not in new: 
            new.append(char)
    return len(new)

# %%
def count_unique(s):
    new= set() 
    for char in s:  
        if char not in new: 
            new.add(char)
    return len(new)

# %%
def count_unique(s):
    new= set(s) 
    return len(new)

# %%
s= 'aabbccc'
a={char for char in s}
len(a)
# Out:
# 3

# %%
new= {'a', 'b', 'c'}

# %%
print(count_unique("aabbccc"))
# Out:
# 3

# %% [markdown]
# ## Operating on a set

# %%
sh= {'hello', True, (2,3,4), None}
len(sh)

# %%
s= set('hello')
len(s)

# %%
a= {23, 45, 55}
23 in a

# %%
56 not in a

# %%
a[2]
a[1:]

# %% [markdown]
# ## Union, intersection, difference,
# union |
#
# intersection &
#
# difference -
#
# symmetric difference ^

# %%
a = {1,2,3,4}
b = {2,3,4,5}
c = {3,4,5,6}
d = {4,5,6,7}
print(a | b | c | d)
# print(a.union(b,c,d))
print(a & b & c & d)
print(a - b)

# %% [markdown]
# ## Question
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
question??
a = {1,2,3,4}
b = {2,3,4,5}
c = {3,4,5,6}
d = {4,5,6,7}
print(a ^ b ^ c ^ d)

# %%
a= {1,4,3}
a.add(0)
a

# %%
a.add({2})
a
